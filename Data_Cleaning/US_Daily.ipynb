# %%
import pandas as pd

# %%
df = pd.read_csv("../Data/Raw Data/us_daily.csv")
df.head()
# Out:
#        date  states    positive    negative  pending  hospitalizedCurrently  \
# 0  20210307      56  28755524.0  74579770.0  11808.0                40212.0
# 1  20210306      56  28714259.0  74449356.0  11783.0                41401.0
# 2  20210305      56  28654639.0  74307155.0  12213.0                42541.0
# 3  20210304      56  28585852.0  74035238.0  12405.0                44172.0
# 4  20210303      56  28520365.0  73857281.0  11778.0                45462.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                878613.0          8137.0          45475.0
# 1                877887.0          8409.0          45453.0
# 2                877384.0          8634.0          45373.0
# 3                874603.0          8970.0          45293.0
# 4                873073.0          9359.0          45214.0
#
#    onVentilatorCurrently  ...          lastModified recovered  total  posNeg  \
# ...

# %%
df = df.drop(['dateChecked', 'lastModified', 'recovered', 'total', 'posNeg', 'hash'], axis= 1)
df.tail()
# Out:
#          date  states  positive  negative  pending  hospitalizedCurrently  \
# 415  20200117       1       0.0       NaN      NaN                    NaN
# 416  20200116       1       0.0       NaN      NaN                    NaN
# 417  20200115       1       0.0       NaN      NaN                    NaN
# 418  20200114       1       0.0       NaN      NaN                    NaN
# 419  20200113       1       NaN       NaN      NaN                    NaN
#
#      hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 415                     NaN             NaN              NaN
# 416                     NaN             NaN              NaN
# 417                     NaN             NaN              NaN
# 418                     NaN             NaN              NaN
# 419                     NaN             NaN              NaN
#
#      onVentilatorCurrently  onVentilatorCumulative  death  hospitalized  \
# 415                    NaN                     NaN    NaN           NaN
# ...

# %%
columns = df.columns
for i in columns:
    df[i] = df[i].fillna(0)   
    df[i] = df[i].astype(int)
    df[i]

# %%
Date = []
for i in df['date']:
    date_object = pd.to_datetime(i, format='%Y%m%d')
    formatted_date = date_object.strftime('%Y-%m-%d')
    Date.append(formatted_date)
df['date'] = Date

# %%
df.head()
# Out:
#          date  states  positive  negative  pending  hospitalizedCurrently  \
# 0  2021-03-07      56  28755524  74579770    11808                  40212
# 1  2021-03-06      56  28714259  74449356    11783                  41401
# 2  2021-03-05      56  28654639  74307155    12213                  42541
# 3  2021-03-04      56  28585852  74035238    12405                  44172
# 4  2021-03-03      56  28520365  73857281    11778                  45462
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                  878613            8137            45475
# 1                  877887            8409            45453
# 2                  877384            8634            45373
# 3                  874603            8970            45293
# 4                  873073            9359            45214
#
#    onVentilatorCurrently  onVentilatorCumulative   death  hospitalized  \
# 0                   2801                    4281  515142        878613
# ...

# %%
df.to_csv("../Data/Clean Data/US_Daily_Cases.csv", index= False)
