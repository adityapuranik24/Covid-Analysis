# %%
import pandas as pd

# %%
df = pd.read_json("../Data/Raw Data/usa-hospital-beds_geo.json", lines= True)
df.head()
# Out:
#    OBJECTID                                      HOSPITAL_NAME HOSPITAL_TYPE  \
# 0         1  Phoenix VA Health Care System (AKA Carl T Hayd...   VA Hospital
# 1         2             Southern Arizona VA Health Care System   VA Hospital
# 2         3           VA Central California Health Care System   VA Hospital
# 3         4  VA Connecticut Healthcare System - West Haven ...   VA Hospital
# 4         5                       Wilmington VA Medical Center   VA Hospital
#
#                HQ_ADDRESS HQ_ADDRESS1     HQ_CITY HQ_STATE  HQ_ZIP_CODE  \
# 0  650 E Indian School Rd        None     Phoenix       AZ        85012
# 1          3601 S 6th Ave        None      Tucson       AZ        85723
# 2      2615 E Clinton Ave        None      Fresno       CA        93703
# 3        950 Campbell Ave        None  West Haven       CT         6516
# 4       1601 Kirkwood Hwy        None  Wilmington       DE        19805
#
# ...

# %%
df = df.drop(['HQ_ADDRESS', 'HQ_ADDRESS1', 'HQ_CITY', 'HQ_STATE', 'HQ_ZIP_CODE', 'latitude', 'longtitude'], axis= 1)

# %%
df['NUM_LICENSED_BEDS'] = df['NUM_LICENSED_BEDS'].fillna(0)
df['NUM_LICENSED_BEDS'] = df['NUM_LICENSED_BEDS'].astype(int)
df['NUM_LICENSED_BEDS']
# Out:
# 0      129
# 1      295
# 2       57
# 3      216
# 4       60
#       ...
# 824    311
# 825    288
# 826    286
# 827    215
# 828    307
# Name: NUM_LICENSED_BEDS, Length: 829, dtype: int32

# %%
df['NUM_STAFFED_BEDS'] = df['NUM_STAFFED_BEDS'].fillna(0)
df['NUM_STAFFED_BEDS'] = df['NUM_STAFFED_BEDS'].astype(int)
df['NUM_STAFFED_BEDS']
# Out:
# 0      129
# 1      295
# 2       57
# 3      216
# 4       60
#       ...
# 824    299
# 825    221
# 826    250
# 827    168
# 828    167
# Name: NUM_STAFFED_BEDS, Length: 829, dtype: int32

# %%
df['PEDI_ICU_BEDS'] = df['PEDI_ICU_BEDS'].fillna(0)
df['PEDI_ICU_BEDS'] = df['PEDI_ICU_BEDS'].astype(int)
df['PEDI_ICU_BEDS']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 824    10
# 825     0
# 826     0
# 827     0
# 828     0
# Name: PEDI_ICU_BEDS, Length: 829, dtype: int32

# %%
df['BED_UTILIZATION'] = df['BED_UTILIZATION'].fillna(0)
df['BED_UTILIZATION'] = df['BED_UTILIZATION'].astype(float)
df['BED_UTILIZATION']
# Out:
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
#          ...
# 824    0.661795
# 825    0.588421
# 826    0.638869
# 827    0.347922
# 828    0.426479
# Name: BED_UTILIZATION, Length: 829, dtype: float64

# %%
df['AVG_VENTILATOR_USAGE'] = df['AVG_VENTILATOR_USAGE'].fillna(0)
df['AVG_VENTILATOR_USAGE'] = df['AVG_VENTILATOR_USAGE'].astype(int)
df['AVG_VENTILATOR_USAGE']
# Out:
# 0       0
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 824     7
# 825    10
# 826    10
# 827     4
# 828     4
# Name: AVG_VENTILATOR_USAGE, Length: 829, dtype: int32

# %%
df.head()
# Out:
#    OBJECTID                                      HOSPITAL_NAME HOSPITAL_TYPE  \
# 0         1  Phoenix VA Health Care System (AKA Carl T Hayd...   VA Hospital
# 1         2             Southern Arizona VA Health Care System   VA Hospital
# 2         3           VA Central California Health Care System   VA Hospital
# 3         4  VA Connecticut Healthcare System - West Haven ...   VA Hospital
# 4         5                       Wilmington VA Medical Center   VA Hospital
#
#   COUNTY_NAME   STATE_NAME  STATE_FIPS  CNTY_FIPS   FIPS  NUM_LICENSED_BEDS  \
# 0    Maricopa      Arizona           4         13   4013                129
# 1        Pima      Arizona           4         19   4019                295
# 2      Fresno   California           6         19   6019                 57
# 3   New Haven  Connecticut           9          9   9009                216
# 4  New Castle     Delaware          10          3  10003                 60
#
# ...

# %%
df.to_csv("../Data/Clean Data/USA_Hospital_Beds.csv", index= False)
