# %%
import pandas as pd

# %%
df = pd.read_csv("../Data/Raw Data/CountryCodeQS.csv")
df.head(100)
# Out:
#                               Country Alpha-2 code Alpha-3 code  Numeric code  \
# 0                         Afghanistan           AF          AFG             4
# 1                             Albania           AL          ALB             8
# 2                             Algeria           DZ          DZA            12
# 3                      American Samoa           AS          ASM            16
# 4                             Andorra           AD          AND            20
# ..                                ...          ...          ...           ...
# 95                              Haiti           HT          HTI           332
# 96  Heard Island and McDonald Islands           HM          HMD           334
# 97      Holy See (Vatican City State)           VA          VAT           336
# 98                           Honduras           HN          HND           340
# 99                          Hong Kong           HK          HKG           344
#
#     Latitude  Longitude
# ...
